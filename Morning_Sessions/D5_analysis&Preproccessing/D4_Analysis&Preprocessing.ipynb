# %% [markdown]
# # Day Objectives:
#
# ## Data Analysis with Pandas
# **To analysize data to the customer requirements**
#
#     * Filtering
#     * Sorting
#     * Grouping
#         * group the data by common categories
#         * groupby() function is used to split the data into groups based on some criteria
#     * Statistical
#     * Plotting
#     * Saving

# %%
import pandas as pd

# %%
data_ = pd.read_csv("datasets_bird.csv")
data_.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
data_.shape
# Out:
# (420, 12)

# %% [markdown]
# ## Filtering

# %%
# access entities only type is SW
data_[data_["type"]=="SW"]
data
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %%
# access entities which is ulnal > 70
data_[data_["ulnal"]>70]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl   tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50   4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22   4.51  41.50
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02   3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00   5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00   7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00   8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00   8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00   9.62  82.58
# 13    13  148.91   6.78  121.35   6.50  44.29  6.33  155.00   6.68  73.71
# 14    14  149.19   6.98  121.48   6.21  43.33  5.39  155.00   6.61  75.65
# 15    15  140.59   6.59  115.97   5.81  39.75  5.61  166.00   7.83  74.86
# 16    16  135.23   6.22  108.78   5.83  37.99  5.13  157.00   7.18  72.44
# ...

# %%
# access entities huml is < 200 and also huml > 100
data_[(data_["huml"] < 200) & (data_["huml"] > 100)].shape
# Out:
# (85, 12)

# %%
data_[data_["huml"] < 200  ][data_["huml"] > 100].shape
# Out:
# E:\_\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (85, 12)

# %%
(data_["huml"] < 100).any()  # or operation
# Out:
# True

# %%
(data_["huml"] < 100).all()
# Out:
# False

# %% [markdown]
# ## Sorting

# %%
data_.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
data_.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
# label sorting
data_.sort_index(axis = 1,ascending=True).head()
# Out:
#     feml  femw   huml  humw  id   tarl  tarw   tibl  tibw type  ulnal  ulnaw
# 0  41.81  3.70  80.78  6.68   0  38.70  3.84   5.50  4.03   SW  72.01   4.88
# 1  47.04  4.30  88.91  6.63   1  41.50  4.01  80.22  4.51   SW  80.53   5.59
# 2  43.07  3.90  79.97  6.37   2  38.31  3.34  75.35  4.04   SW  69.26   5.28
# 3  40.04  3.52  77.65  5.70   3  35.78  3.41  69.17  3.40   SW  65.76   4.77
# 4  33.95  2.72  62.80  4.84   4  31.88  3.13  56.27  2.96   SW  52.09   3.73

# %%
data_.sort_index(axis = 1,ascending=False).head()
# Out:
#    ulnaw  ulnal type  tibw   tibl  tarw   tarl  id  humw   huml  femw   feml
# 0   4.88  72.01   SW  4.03   5.50  3.84  38.70   0  6.68  80.78  3.70  41.81
# 1   5.59  80.53   SW  4.51  80.22  4.01  41.50   1  6.63  88.91  4.30  47.04
# 2   5.28  69.26   SW  4.04  75.35  3.34  38.31   2  6.37  79.97  3.90  43.07
# 3   4.77  65.76   SW  3.40  69.17  3.41  35.78   3  5.70  77.65  3.52  40.04
# 4   3.73  52.09   SW  2.96  56.27  3.13  31.88   4  4.84  62.80  2.72  33.95

# %%
data_
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %%
data_.sort_values(by = "huml",axis = 0)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48  1.12   24.91   0.92   17.55
# 369  369   13.48   1.27   16.00   1.00   12.67  1.10   23.12   0.88   16.34
# 376  376   13.52   1.28   17.88   1.07   15.10  1.05   25.14   1.23   17.81
# 414  414   13.63   1.16   15.22   1.06   13.75  0.99   23.13   0.96   15.62
# 371  371   13.67   1.27   17.52   1.08   12.77  1.16   25.47   0.98   18.15
# 372  372   14.51   1.49   18.79   1.12   14.07  1.01   25.85   1.00   18.38
# 375  375   14.61   1.37   20.30   1.23   14.28  1.04   25.09   0.88   17.39
# ...

# %%
data_["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
data_.sort_values(by = ["huml","humw"],axis = 0)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48  1.12   24.91   0.92   17.55
# 369  369   13.48   1.27   16.00   1.00   12.67  1.10   23.12   0.88   16.34
# 376  376   13.52   1.28   17.88   1.07   15.10  1.05   25.14   1.23   17.81
# 414  414   13.63   1.16   15.22   1.06   13.75  0.99   23.13   0.96   15.62
# 371  371   13.67   1.27   17.52   1.08   12.77  1.16   25.47   0.98   18.15
# 372  372   14.51   1.49   18.79   1.12   14.07  1.01   25.85   1.00   18.38
# 375  375   14.61   1.37   20.30   1.23   14.28  1.04   25.09   0.88   17.39
# ...

# %%
help(data_.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last') method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis
#
#     Parameters
#     ----------
#     by : str or list of str
#         Name or list of names to sort by.
#
#         - if `axis` is 0 or `'index'` then `by` may contain index
#           levels and/or column labels
#         - if `axis` is 1 or `'columns'` then `by` may contain column
#           levels and/or index labels
#
#         .. versionchanged:: 0.23.0
#            Allow specifying index or column level names.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#          Axis to be sorted
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
#          orders.  If this is a list of bools, must match the length of
#          the by.
# ...

# %% [markdown]
# ## Grouping

# %%
data_.sample(3)  # birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 190  190  32.02  2.99  27.70   2.38  38.27  2.64  53.33  2.71  31.00  2.45
# 231  231  42.46  3.49  47.34   3.27  36.03  2.94  49.17  2.68  34.38  2.25
# 275  275  39.98  3.34  47.50   2.64  28.57  2.53  42.96  2.20  27.66  1.67
#
#     type
# 190    T
# 231    R
# 275    P

# %%
data_["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
groups = data_.groupby("type")
groups

# %%
data_
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %%
groups.first()
# Out:
#        id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# type
# P     254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22
# R     204   63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19
# SO    292   29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33
# SW      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70
# T     181   43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41
# W     116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
#
#       tarw
# type
# P     1.62
# R     3.82
# SO    1.78
# SW    3.84
# T     2.83
# W     6.77

# %%
groups.last()
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
# R     253  35.63  2.40  42.67   2.02  28.51  2.41  42.64  2.46  21.05  3.12
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# SW    115  98.73  6.48  91.69   5.31  35.34  4.02  92.36  4.46  50.53  2.69
# T     203  39.64  4.07  37.32   2.98  45.50  3.42  64.45  3.37  37.77  2.86
# W     180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34

# %%
for name,group in groups:
    print("*",name,"*",group)
# Out:
# * P *       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
groups.get_group("SW")
# Out:
#       feml  femw    huml   humw   id   tarl   tarw    tibl  tibw   ulnal  \
# 0    41.81  3.70   80.78   6.68    0  38.70   3.84    5.50  4.03   72.01
# 1    47.04  4.30   88.91   6.63    1  41.50   4.01   80.22  4.51   80.53
# 2    43.07  3.90   79.97   6.37    2  38.31   3.34   75.35  4.04   69.26
# 3    40.04  3.52   77.65   5.70    3  35.78   3.41   69.17  3.40   65.76
# 4    33.95  2.72   62.80   4.84    4  31.88   3.13   56.27  2.96   52.09
# 5    49.52  4.41   61.92   4.78    5  29.07   2.83   56.95  2.73   50.46
# 6    42.07  3.41   79.73   5.94    6  37.22   3.64   71.26  3.56   67.39
# 7    44.46  3.78   86.98   5.68    7  37.94   3.81   76.02  3.81   74.52
# 8    59.33  5.45  118.20   7.82    8  61.62   4.37  110.00  5.58  116.64
# 9    70.96  7.44  145.00  10.42    9  78.67   6.34  120.00  7.31  144.00
# 10   80.25  7.85  165.00  11.45   10  86.61   6.63  143.00  8.25  156.00
# 11   56.02  7.02  186.00   9.83   11  90.80   4.59  185.00  8.07  152.00
# ...

# %%
groups.sum()
# Out:
#          id      huml    humw     ulnal   ulnaw     feml    femw     tibl  \
# type
# P     10355   1308.11  115.49   1488.74   94.10  1072.26   87.70  1591.49
# R     11425   4346.72  303.28   4916.78  235.85  3101.00  263.34  4493.87
# SO    45504   2839.86  257.78   3326.16  221.47  2715.70  215.08  4577.08
# SW     6670  12789.13  745.18  12963.64  605.71  4891.68  495.99  9896.78
# T      4416   1051.09  110.08   1049.20   79.85  1064.38   87.85  1520.09
# W      9620   4753.65  299.46   5076.59  266.67  2567.65  199.59  4949.75
#
#         tibw     tarl    tarw
# type
# P      79.64   979.92   72.30
# R     247.46  2899.15  248.62
# SO    196.69  3307.86  172.72
# SW    523.57  5238.12  481.39
# T      79.39   921.99   73.23
# W     206.65  3090.32  179.42

# %%
groups.mean()
# Out:
#          id        huml      humw       ulnal     ulnaw       feml      femw  \
# type
# P     272.5   34.423947  3.039211   39.177368  2.476316  28.217368  2.307895
# R     228.5   86.934400  6.065600  100.342449  4.813265  62.020000  5.266800
# SO    355.5   22.361102  2.029764   26.398095  1.743858  21.383465  1.680313
# SW     57.5  110.251121  6.423966  111.755517  5.221638  42.169655  4.275776
# T     192.0   45.699565  4.786087   45.617391  3.471739  46.277391  3.819565
# W     148.0   73.133077  4.607077   78.101385  4.102615  40.119531  3.118594
#
#            tibl      tibw       tarl      tarw
# type
# P     41.881316  2.095789  25.787368  1.902632
# R     89.877400  4.949200  59.166327  5.073878
# SO    36.326032  1.548740  25.842656  1.349375
# SW    85.317069  4.513534  45.156207  4.149914
# T     66.090870  3.451739  40.086522  3.183913
# W     76.150000  3.179231  47.543385  2.760308

# %%
gps = data_.groupby(["type","id"])
gps

# %%
gps.mean()
# Out:
#             huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw
# type id
# P    254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81  25.22  1.62
#      255   30.60  2.45   25.90   1.87  32.36  2.10   50.25  1.88  33.58  1.88
#      256   30.25  2.29   25.14   1.87  31.61  2.18   50.98  2.00  33.50  1.93
#      257   42.52  2.99   36.73   2.91  52.24  3.81   81.57  3.71  61.27  2.71
#      258   45.60  3.35   38.73   3.52  54.45  4.10   83.59  3.72  63.91  2.67
#      259   43.97  3.54   38.38   3.14  52.49  4.25   83.15  4.12  61.08  3.04
#      260   46.38  3.41   39.80   3.48  54.67  4.08   85.88  4.04  63.75  3.09
#      261   45.57  4.64   57.13   2.93  28.32  2.26   36.95  1.96  19.75  2.16
#      262   33.81  2.80   42.82   2.22  18.88  1.45   26.28  1.31  14.45  1.29
#      263   31.72  2.64   40.00   1.99  20.36  1.59   32.21  1.62  17.72  1.52
#      264    9.85  2.88   14.73   1.73  16.27  1.22   20.89  1.25   7.77  1.23
# ...

# %%
2016 -- 20team -- csk
2017 -- 15team
2018 -- 20team

# %% [markdown]
# ## Statistical

# %%
data_["huml"].mean()
# Out:
# 64.6505011933174

# %%
data_.median()
# Out:
# id       209.500
# huml      44.180
# humw       3.500
# ulnal     43.710
# ulnaw      2.945
# feml      31.130
# femw       2.520
# tibl      52.120
# tibw       2.490
# tarl      31.740
# tarw       2.230
# dtype: float64

# %%
data_["huml"].median()
# Out:
# 44.18

# %%
data_["huml"].mode() # frequently occured values
# Out:
# 0    145.0
# dtype: float64

# %%
data_[data_["huml"] == 145]
# Out:
#       id   huml   humw  ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 9      9  145.0  10.42  144.0   7.05  70.96  7.44  120.00  7.31  78.67  6.34
# 232  232  145.0  10.37  188.0   7.92  77.09  7.75  125.48  7.90  51.99  9.64
# 234  234  145.0  10.31  188.0   7.85  78.86  7.72  126.54  7.13  53.64  8.88
#
#     type
# 9     SW
# 232    R
# 234    R

# %%
data_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
# id       420 non-null int64
# huml     419 non-null float64
# humw     419 non-null float64
# ulnal    417 non-null float64
# ulnaw    418 non-null float64
# feml     418 non-null float64
# femw     419 non-null float64
# tibl     418 non-null float64
# tibw     419 non-null float64
# tarl     419 non-null float64
# tarw     419 non-null float64
# type     420 non-null object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB

# %%
data_org = data_.describe()
data_org
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %% [markdown]
# ## Plotting

# %%
data_.tail(3)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 417   SO
# 418   SO
# 419   SO

# %%
import matplotlib.pyplot as plt

# %%
data_.plot()

# %%
data_["huml"].plot()
plt.show()

# %%
data_["huml"][0:50].plot()
plt.show()

# %% [markdown]
# ## Saving

# %%
data_.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
data_org
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %%
data_org.to_excel("df_descri.xlsx")

# %%
data_org.to_csv("df_descri.csv")

# %%
data_["huml"]["humw"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-628648fa5aba> in <module>
# ----> 1 data_["huml"]["humw"].plot()
#
# E:\_\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# E:\_\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
# ...

# %%
data_["huml"].plot()
data_["humw"].plot()
plt.show()

# %%
data_.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
data_.loc[4]
# Out:
# id           4
# huml      62.8
# humw      4.84
# ulnal    52.09
# ulnaw     3.73
# feml     33.95
# femw      2.72
# tibl     56.27
# tibw      2.96
# tarl     31.88
# tarw      3.13
# type        SW
# Name: 4, dtype: object

# %%
data_.iloc[4]
# Out:
# id           4
# huml      62.8
# humw      4.84
# ulnal    52.09
# ulnaw     3.73
# feml     33.95
# femw      2.72
# tibl     56.27
# tibw      2.96
# tarl     31.88
# tarw      3.13
# type        SW
# Name: 4, dtype: object

# %%
data_.loc[4,"type"]
# Out:
# 'SW'

# %%
data_.loc[[4,2,1,200],"type"]
# Out:
# 4      SW
# 2      SW
# 1      SW
# 200     T
# Name: type, dtype: object

# %% [markdown]
# # Data Preprocessing with scikit-learn
#
# * Loading data
# * Exploring data
# * Cleaning Data
# * Transforming data

# %% [markdown]
# * will learn data preprocessing techniques with scikit-learn, one of the most popular frameworks used for industry data science
# * The scikit-learn library includes tools for data preprocessing and data mining. It is imported in Python via the statement import sklearn.
# ![ddd.PNG](ddd.PNG)
#
# ### Data Imputation
# * if the dataset is missing too many values, we just don't use it
# *  if only a few of the values are missing, we can perform data imputation to substitute the missing data with some other value(s).
# * There are many different methods for data imputation
#     * Using the mean value
#     * Using the median value
#     * Using the most frequent value
#     * Filling in missing values with a constant
#
# ### Data Range
# * Scale data by compressing it into a fixed range
# * One of the biggest use cases for this is compressing data into the range [0, 1]
# * MinMaxScaler
# ![minmax.PNG](attachment:minmax.PNG)
#
# ### Standardizing Data
# * it rescales the data to have mean = 0 and varience(statistical measure that provides indicator of data's dispresion) = 1
#
# * Standardization rescales data so that it has a mean of 0 and a standard deviation of 1.
# * The formula for this is:  (𝑥 − 𝜇)/𝜎
#
#     * We subtract the mean (𝜇) from each value (x) and then divide by the standard deviation (𝜎)
#
# ![stddata.PNG](attachment:stddata.PNG)
# ![std.PNG](attachment:std.PNG)
#
# ### Normalizing Data
#
# * Normalization rescales the data into the range [0, 1].
# * The formula for this is:  (𝑥 −𝑥𝑚𝑖𝑛)/(𝑥𝑚𝑎𝑥 −𝑥𝑚𝑖𝑛)
#
#
# ### Robust Scaling

# %%
import sklearn

# %% [markdown]
# pip install sklearn

# %%
pip install sklearn
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install sklearn
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %% [markdown]
# ## Data Imputation

# %%
"Name" : pd.Series(["siva kumar","mahesh","chaitanya","bharath","Geetha"

# %%
dic_ = { "Name" : pd.Series([12,13,14,15,16],index = [0,1,3,4,5]),
        "age" : pd.Series([23,32,31,22,20],index = [0,2,3,4,5]),
       "Gender": pd.Series([1,1,1,1,0],index=[0,1,2,4,5])
}
df_data = pd.DataFrame(dic_)
df_data
# Out:
#    Name   age  Gender
# 0  12.0  23.0     1.0
# 1  13.0   NaN     1.0
# 2   NaN  32.0     1.0
# 3  14.0  31.0     NaN
# 4  15.0  22.0     1.0
# 5  16.0  20.0     0.0

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")
si
# Out:
# SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)

# %%
si.fit_transform(df_data)
# Out:
# array([[12. , 23. ,  1. ],
#        [13. , 25.6,  1. ],
#        [14. , 32. ,  1. ],
#        [14. , 31. ,  0.8],
#        [15. , 22. ,  1. ],
#        [16. , 20. ,  0. ]])

# %%
df_data['age'].mean()
# Out:
# 25.6

# %%
si = SimpleImputer(strategy="median")
si.fit_transform(df_data)
# Out:
# array([[12., 23.,  1.],
#        [13., 23.,  1.],
#        [14., 32.,  1.],
#        [14., 31.,  1.],
#        [15., 22.,  1.],
#        [16., 20.,  0.]])

# %%
df_data['Gender'].median()
# Out:
# 1.0

# %%
si = SimpleImputer(strategy="most_frequent") # mode
si.fit_transform(df_data)
# Out:
# array([[12., 23.,  1.],
#        [13., 20.,  1.],
#        [12., 32.,  1.],
#        [14., 31.,  1.],
#        [15., 22.,  1.],
#        [16., 20.,  0.]])

# %%
si = SimpleImputer(strategy="constant")  # default it taskes 0
si.fit_transform(df_data)
# Out:
# array([[12., 23.,  1.],
#        [13.,  0.,  1.],
#        [ 0., 32.,  1.],
#        [14., 31.,  0.],
#        [15., 22.,  1.],
#        [16., 20.,  0.]])

# %%
si = SimpleImputer(strategy="constant",fill_value = 100)  
si.fit_transform(df_data)
# Out:
# array([[ 12.,  23.,   1.],
#        [ 13., 100.,   1.],
#        [100.,  32.,   1.],
#        [ 14.,  31., 100.],
#        [ 15.,  22.,   1.],
#        [ 16.,  20.,   0.]])

# %%
si
# Out:
# SimpleImputer(copy=True, fill_value=None, missing_values=nan,
#        strategy='constant', verbose=0)

# %% [markdown]
# ## Data Range

# %%
import numpy as np
x = np.array([1,1.1,1.5,3,2,2.1,100,70])
y = np.array([2,1,1.2,3,3,4,109,80])
plt.scatter(x,y)

# %%
import pandas as pd
data_rg = pd.read_csv("https://raw.githubusercontent.com/Apssdc-dataanalysis2/DataAnalysis2/master/Morning_Sessions/D5_analysis%26Preproccessing/Advertising.csv")

data_rg.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
(data_rg["TV"][0] - data_rg["TV"].min()) / (data_rg["TV"].max() - data_rg["TV"].min() )
# Out:
# 0.7757862698681096

# %%
(data_rg["TV"][1] - data_rg["TV"].min()) / (data_rg["TV"].max() - data_rg["TV"].min() )
# Out:
# 0.14812309773419005

# %% [markdown]
# 0 - 1 scale

# %%
from sklearn.preprocessing import MinMaxScaler
mmscale = MinMaxScaler()
result = mmscale.fit_transform(data_rg)
result
# Out:
# array([[0.77578627, 0.76209677, 0.60598065, 0.80708661],
#        [0.1481231 , 0.79233871, 0.39401935, 0.34645669],
#        [0.0557998 , 0.92540323, 0.60686016, 0.30314961],
#        [0.50997633, 0.83266129, 0.51187335, 0.66535433],
#        [0.60906324, 0.21774194, 0.51099384, 0.44488189],
#        [0.02705445, 0.9858871 , 0.65699208, 0.22047244],
#        [0.19208657, 0.66129032, 0.20404573, 0.4015748 ],
#        [0.4041258 , 0.39516129, 0.09938434, 0.45669291],
#        [0.02671627, 0.04233871, 0.00615655, 0.12598425],
#        [0.67331755, 0.05241935, 0.18381706, 0.35433071],
#        [0.2211701 , 0.11693548, 0.21020229, 0.27559055],
#        [0.72370646, 0.48387097, 0.03254178, 0.62204724],
#        [0.07811972, 0.70766129, 0.5769569 , 0.2992126 ],
#        [0.32735881, 0.15322581, 0.06068602, 0.31889764],
#        [0.68785932, 0.66330645, 0.40193492, 0.68503937],
#        [0.65843761, 0.96169355, 0.46262093, 0.81889764],
# ...

# %%
mmscale.fit_transform(data_rg).min()
# Out:
# 0.0

# %%
mmscale.fit_transform(data_rg).max()
# Out:
# 1.0

# %%
data_rg.max()
# Out:
# TV           296.4
# radio         49.6
# newspaper    114.0
# sales         27.0
# dtype: float64

# %%
data_rg.min()
# Out:
# TV           0.7
# radio        0.0
# newspaper    0.3
# sales        1.6
# dtype: float64

# %%
mmscale.fit(data_rg)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
res = mmscale.transform(data_rg)
res
# Out:
# array([[0.77578627, 0.76209677, 0.60598065, 0.80708661],
#        [0.1481231 , 0.79233871, 0.39401935, 0.34645669],
#        [0.0557998 , 0.92540323, 0.60686016, 0.30314961],
#        [0.50997633, 0.83266129, 0.51187335, 0.66535433],
#        [0.60906324, 0.21774194, 0.51099384, 0.44488189],
#        [0.02705445, 0.9858871 , 0.65699208, 0.22047244],
#        [0.19208657, 0.66129032, 0.20404573, 0.4015748 ],
#        [0.4041258 , 0.39516129, 0.09938434, 0.45669291],
#        [0.02671627, 0.04233871, 0.00615655, 0.12598425],
#        [0.67331755, 0.05241935, 0.18381706, 0.35433071],
#        [0.2211701 , 0.11693548, 0.21020229, 0.27559055],
#        [0.72370646, 0.48387097, 0.03254178, 0.62204724],
#        [0.07811972, 0.70766129, 0.5769569 , 0.2992126 ],
#        [0.32735881, 0.15322581, 0.06068602, 0.31889764],
#        [0.68785932, 0.66330645, 0.40193492, 0.68503937],
#        [0.65843761, 0.96169355, 0.46262093, 0.81889764],
# ...

# %%
res == result
# Out:
# array([[ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
#        [ True,  True,  True,  True],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mmscale = MinMaxScaler()
rescale = mmscale.fit_transform(data_rg)
rescale
# Out:
# array([[0.77578627, 0.76209677, 0.60598065, 0.80708661],
#        [0.1481231 , 0.79233871, 0.39401935, 0.34645669],
#        [0.0557998 , 0.92540323, 0.60686016, 0.30314961],
#        [0.50997633, 0.83266129, 0.51187335, 0.66535433],
#        [0.60906324, 0.21774194, 0.51099384, 0.44488189],
#        [0.02705445, 0.9858871 , 0.65699208, 0.22047244],
#        [0.19208657, 0.66129032, 0.20404573, 0.4015748 ],
#        [0.4041258 , 0.39516129, 0.09938434, 0.45669291],
#        [0.02671627, 0.04233871, 0.00615655, 0.12598425],
#        [0.67331755, 0.05241935, 0.18381706, 0.35433071],
#        [0.2211701 , 0.11693548, 0.21020229, 0.27559055],
#        [0.72370646, 0.48387097, 0.03254178, 0.62204724],
#        [0.07811972, 0.70766129, 0.5769569 , 0.2992126 ],
#        [0.32735881, 0.15322581, 0.06068602, 0.31889764],
#        [0.68785932, 0.66330645, 0.40193492, 0.68503937],
#        [0.65843761, 0.96169355, 0.46262093, 0.81889764],
# ...

# %%
from sklearn.preprocessing import Normalizer
n = Normalizer()
nor_rescale = n.fit_transform(data_rg)
nor_rescale
# Out:
# array([[0.94211621, 0.15476746, 0.28333091, 0.09048574],
#        [0.59113524, 0.52205877, 0.59910561, 0.13815296],
#        [0.20142628, 0.53752711, 0.81156054, 0.10891072],
#        [0.89863215, 0.24497365, 0.34699657, 0.10973396],
#        [0.94788063, 0.05662119, 0.30617383, 0.06763086],
#        [0.09640672, 0.54187225, 0.83109241, 0.07978487],
#        [0.80725471, 0.46048617, 0.32992149, 0.16566271],
#        [0.97684844, 0.15928643, 0.09427156, 0.10727454],
#        [0.84982063, 0.20751434, 0.09881635, 0.47431849],
#        [0.99295394, 0.01292132, 0.10535848, 0.05267924],
#        [0.92901149, 0.08151689, 0.34012221, 0.12086988],
#        [0.99043367, 0.11071452, 0.01845242, 0.08026803],
#        [0.30163094, 0.44484227, 0.83518819, 0.11659683],
#        [0.98945567, 0.0771268 , 0.0730675 , 0.09843815],
#        [0.95983344, 0.15472082, 0.21632699, 0.08935245],
#        [0.93412001, 0.22803237, 0.25289124, 0.10708438],
# ...

# %%
rescale == nor_rescale
# Out:
# array([[False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
# ...
