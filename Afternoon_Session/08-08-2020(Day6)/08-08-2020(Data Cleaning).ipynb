# %%
import pandas as pd
import numpy as np

# %%
a = {"names":["mounika","alekhya","archana","naga","archana"],"desg":["trainer","software","teacher",np.nan,"teacher"]}
data = pd.DataFrame(a)

# %%
data
# Out:
#      names      desg
# 0  mounika   trainer
# 1  alekhya  software
# 2  archana   teacher
# 3     naga       NaN
# 4  archana   teacher

# %%
d = data.drop_duplicates().dropna()
d
# Out:
#      names      desg
# 0  mounika   trainer
# 1  alekhya  software
# 2  archana   teacher

# %%
d.dropna()
# Out:
#      names      desg
# 0  mounika   trainer
# 1  alekhya  software
# 2  archana   teacher

# %%
midx = pd.MultiIndex(levels=[["cow","buffalo","falcon"],["speed","weight","length"]],
                     codes=[[0,0,0,1,1,1,2,2,2],[0,1,2,0,1,2,0,1,2]])

# %%
midx
# Out:
# MultiIndex(levels=[['cow', 'buffalo', 'falcon'], ['speed', 'weight', 'length']],
#            codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
s = pd.DataFrame(index=midx,columns=["big","small"],data=[[45,30],[200,40],[6,45],[45,67],[5,3.4],[9,45],[5,3],[6,3],[9,6]])

# %%
s
# Out:
#                 big  small
# cow     speed    45   30.0
#         weight  200   40.0
#         length    6   45.0
# buffalo speed    45   67.0
#         weight    5    3.4
#         length    9   45.0
# falcon  speed     5    3.0
#         weight    6    3.0
#         length    9    6.0

# %%
s.drop(index="buffalo",columns="small")
# Out:
#                big
# cow    speed    45
#        weight  200
#        length    6
# falcon speed     5
#        weight    6
#        length    9

# %%
s.drop(index="length",level=1)
# Out:
#                 big  small
# cow     speed    45   30.0
#         weight  200   40.0
# buffalo speed    45   67.0
#         weight    5    3.4
# falcon  speed     5    3.0
#         weight    6    3.0

# %%
df = pd.read_csv("movie_metadata.csv")
df
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# ...

# %%
df.head(2)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df["movie_imdb_link"].sample(5)
# Out:
# 3675    http://www.imdb.com/title/tt0280778/?ref_=fn_t...
# 1627    http://www.imdb.com/title/tt1605783/?ref_=fn_t...
# 3009    http://www.imdb.com/title/tt1124052/?ref_=fn_t...
# 4090    http://www.imdb.com/title/tt0174336/?ref_=fn_t...
# 2777    http://www.imdb.com/title/tt0094947/?ref_=fn_t...
# Name: movie_imdb_link, dtype: object

# %%
df["movie_imdb_link"].head(5)
# Out:
# 0    http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 1    http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2    http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# 3    http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# 4    http://www.imdb.com/title/tt5289954/?ref_=fn_t...
# Name: movie_imdb_link, dtype: object

# %%
df.isnull() # df.isna()
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# 5     False          False                   False     False
# 6     False          False                   False     False
# 7     False          False                   False     False
# 8     False          False                   False     False
# 9     False          False                   False     False
# 10    False          False                   False     False
# 11    False          False                   False     False
# 12    False          False                   False     False
# 13    False          False                   False     False
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 2698

# %%
clean_d = df.dropna()
clean_d
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# 11               Color        Bryan Singer                   434.0     169.0
# ...

# %%
df.shape
# Out:
# (5043, 28)

# %%
clean_d.shape
# Out:
# (3756, 28)

# %%
df.fillna(value = 0,inplace=True)

# %%
df.head(5)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4      0        Doug Walker                     0.0       0.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     0.0        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df[["color","director_name"]]=df[["color","director_name"]].fillna(value=0,inplace=True)

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df["language"].fillna("no info",inplace=True)

# %%
df["duration"].fillna(df["duration"].mean(),inplace=True)

# %%
clean = clean_d[clean_d.duplicated()]
clean.shape # duplicated number of rows and columns
# Out:
# (33, 28)

# %%
clean_d.shape
# Out:
# (3756, 28)

# %%
clean_d[clean_d.duplicated()]
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 137              Color           David Yates                   248.0
# 187              Color           Bill Condon                   322.0
# 303              Color            Joe Wright                   256.0
# 389              Color            Josh Trank                   369.0
# 395              Color             Rob Cohen                   187.0
# 590              Color          Brett Ratner                   245.0
# 656              Color        Paul Verhoeven                   196.0
# 794              Color           Joss Whedon                   703.0
# 1220             Color   Angelina Jolie Pitt                   322.0
# 1305             Color         Paul McGuigan                   159.0
# 1449             Color         Albert Hughes                   208.0
# 2169             Color         Paul McGuigan                    98.0
# 2292             Color              Frank Oz                   168.0
# ...

# %%
## how to remove duplicates for particular column

# %%
df.drop(["color"],axis=1)
# Out:
#      director_name  num_critic_for_reviews  duration  director_facebook_likes  \
# 0             None                   723.0     178.0                      0.0
# 1             None                   302.0     169.0                    563.0
# 2             None                   602.0     148.0                      0.0
# 3             None                   813.0     164.0                  22000.0
# 4             None                     0.0       0.0                    131.0
# 5             None                   462.0     132.0                    475.0
# 6             None                   392.0     156.0                      0.0
# 7             None                   324.0     100.0                     15.0
# 8             None                   635.0     141.0                      0.0
# 9             None                   375.0     153.0                    282.0
# 10            None                   673.0     183.0                      0.0
# ...

# %% [markdown]
# ### Identifying and eliminating outliers

# %%
df1 = pd.read_csv("movie_metadata.csv")
df1
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# ...

# %%
import seaborn as sns
sns.boxplot(df1["budget"])

# %%
import matplotlib.pyplot as plt
plt.scatter(df1["budget"],df1["title_year"])

# %%
from scipy import stats
z = np.abs(stats.zscore(clean_d["budget"]))
z1 = pd.DataFrame(z)
z1.head()
# Out:
#           0
# 0  0.844159
# 1  1.122944
# 2  0.879560
# 3  0.901686
# 4  0.962311

# %%
np.where(z<0.5)
# Out:
# (array([  28,   49,   57, ..., 3753, 3754, 3755], dtype=int64),)

# %%
clean_d["budget"][z<0.5]
# Out:
# 29      150000000.0
# 50      105000000.0
# 59      140000000.0
# 69      140000000.0
# 72      145000000.0
# 100      38000000.0
# 101     150000000.0
# 104     150000000.0
# 109     155000000.0
# 110     155000000.0
# 111     140000000.0
# 112     150000000.0
# 113     155000000.0
# 114     150000000.0
# 115     150000000.0
# 116     150000000.0
# 117     150000000.0
# 118     150000000.0
# 119     150000000.0
# 120     150000000.0
# 121     150000000.0
# 122     150000000.0
# 123     150000000.0
# 124     150000000.0
# 125     150000000.0
# 126     150000000.0
# 128     150000000.0
# 129     150000000.0
# 130     150000000.0
# 131     150000000.0
#            ...
# 4930       150000.0
# 4931       180000.0
# 4933       160000.0
# 4936        83532.0
# 4941       160000.0
# 4955       100000.0
# 4956       100000.0
# 4959       100000.0
# 4962        40000.0
# 4964       200000.0
# 4971     15000000.0
# 4973        60000.0
# 4975        60000.0
# 4977        65000.0
# ...

# %% [markdown]
# #### Data Imputation

# %%
d1 = pd.DataFrame({"names":["mounika","alekhya","archana","naga"],"grades":["A","2","B",np.nan]})
d1
# Out:
#      names grades
# 0  mounika      A
# 1  alekhya      2
# 2  archana      B
# 3     naga    NaN

# %%
d1.isna().sum()
# Out:
# names     0
# grades    1
# dtype: int64

# %%
df1 = d1.fillna(0)
df1["grades"]
# Out:
# 0    A
# 1    2
# 2    B
# 3    0
# Name: grades, dtype: object

# %%
d1["grades"]
# Out:
# 0      A
# 1      2
# 2      B
# 3    NaN
# Name: grades, dtype: object

# %%
cnt = 0
for row in d1["grades"]:
    try:
        int(row)
        d1.loc[cnt,"grades"]=np.nan
    except ValueError:
        pass
    cnt+=1

# %%
d1.loc[1,["grades"]]=np.nan

# %%
d1["grades"]
# Out:
# 0      A
# 1    NaN
# 2      B
# 3    NaN
# Name: grades, dtype: object

# %%
m = ["?","--","na","n/a"]
pd.read_csv("movies.csv",na_values=m)

# %%
clean_d.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
clean_d["director_name"][clean_d["budget"]>100000]
# Out:
# 0              James Cameron
# 1             Gore Verbinski
# 2                 Sam Mendes
# 3          Christopher Nolan
# 5             Andrew Stanton
# 6                  Sam Raimi
# 7               Nathan Greno
# 8                Joss Whedon
# 9                David Yates
# 10               Zack Snyder
# 11              Bryan Singer
# 12              Marc Forster
# 13            Gore Verbinski
# 14            Gore Verbinski
# 15               Zack Snyder
# 16            Andrew Adamson
# 17               Joss Whedon
# 18              Rob Marshall
# 19          Barry Sonnenfeld
# 20             Peter Jackson
# 21                 Marc Webb
# 22              Ridley Scott
# 23             Peter Jackson
# 24               Chris Weitz
# 25             Peter Jackson
# 26             James Cameron
# 27             Anthony Russo
# 28                Peter Berg
# 29           Colin Trevorrow
# 30                Sam Mendes
#                 ...
# 4852             Kevin Smith
# ...
